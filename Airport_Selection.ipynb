# %% [markdown]
# <a href="https://colab.research.google.com/github/Chu-Yichen/QM2-Group-19/blob/main/Airport_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# JSON data as a string
json_data = """
[
    {
        "Rank": 1,
        "Country": "United States",
        "Airport": "Hartsfield-Jackson Atlanta International Airport",
        "Number of Passengers": 104653451
    },
    {
        "Rank": 2,
        "Country": "United Arab Emirates",
        "Airport": "Dubai International Airport",
        "Number of Passengers": 86994365
    },
    {
        "Rank": 3,
        "Country": "United States",
        "Airport": "Dallas/Ft Worth International Airport",
        "Number of Passengers": 81755538
    },
    {
        "Rank": 4,
        "Country": "United Kingdom",
        "Airport": "Heathrow Airport",
        "Number of Passengers": 79183364
    },
    {
        "Rank": 5,
        "Country": "Japan",
        "Airport": "Tokyo International (Haneda) Airport",
        "Number of Passengers": 78719302
    },
    {
        "Rank": 6,
        "Country": "United States",
        "Airport": "Denver International Airport",
        "Number of Passengers": 77837917
    },
    {
        "Rank": 7,
        "Country": "Turkey",
        "Airport": "Istanbul International Airport",
        "Number of Passengers": 76027321
    },
    {
        "Rank": 8,
        "Country": "United States",
        "Airport": "Los Angeles International Airport",
        "Number of Passengers": 75050875
    },
    {
        "Rank": 9,
        "Country": "United States",
        "Airport": "O'Hare International Airport",
        "Number of Passengers": 73894226
    },
    {
        "Rank": 10,
        "Country": "India",
        "Airport": "Indira Gandhi International Airport",
        "Number of Passengers": 72214841
    },
    {
        "Rank": 11,
        "Country": "France",
        "Airport": "Aéroport de Paris-Charles de Gaulle",
        "Number of Passengers": 67421316
    },
    {
        "Rank": 12,
        "Country": "China",
        "Airport": "Guangzhou Bai Yun International Airport",
        "Number of Passengers": 63169169
    },
    {
        "Rank": 13,
        "Country": "United States",
        "Airport": "John F. Kennedy International Airport",
        "Number of Passengers": 62464331
    },
    {
        "Rank": 14,
        "Country": "Netherlands",
        "Airport": "Amsterdam Airport Schiphol",
        "Number of Passengers": 61889586
    },
    {
        "Rank": 15,
        "Country": "Spain",
        "Airport": "Aeropuerto de Adolfo Suárez Madrid-Barajas",
        "Number of Passengers": 60181604
    },
    {
        "Rank": 16,
        "Country": "Germany",
        "Airport": "Flughafen Frankfurt/Main",
        "Number of Passengers": 59355389
    },
    {
        "Rank": 17,
        "Country": "Singapore",
        "Airport": "Singapore Changi Airport",
        "Number of Passengers": 58946000
    },
    {
        "Rank": 18,
        "Country": "United States",
        "Airport": "Orlando International Airport",
        "Number of Passengers": 57735726
    },
    {
        "Rank": 19,
        "Country": "United States",
        "Airport": "McCarran International Airport",
        "Number of Passengers": 57666456
    },
    {
        "Rank": 20,
        "Country": "Republic of Korea",
        "Airport": "Incheon International Airport",
        "Number of Passengers": 56235412
    },
    {
        "Rank": 21,
        "Country": "China",
        "Airport": "Pudong International Airport",
        "Number of Passengers": 54476397
    },
    {
        "Rank": 22,
        "Country": "United States",
        "Airport": "Charlotte Douglas International Airport",
        "Number of Passengers": 53445770
    },
    {
        "Rank": 23,
        "Country": "China",
        "Airport": "Beijing Capital International Airport",
        "Number of Passengers": 52879156
    },
    {
        "Rank": 24,
        "Country": "China",
        "Airport": "Shenzhen Baoan International Airport",
        "Number of Passengers": 52734934
    },
    {
        "Rank": 25,
        "Country": "United States",
        "Airport": "Miami International Airport",
        "Number of Passengers": 52340934
    },
    {
        "Rank": 26,
        "Country": "Thailand",
        "Airport": "Suvarnabhumi International Airport",
        "Number of Passengers": 51699104
    },
    {
        "Rank": 27,
        "Country": "India",
        "Airport": "Chhatrapati Shivaji International Airport",
        "Number of Passengers": 51589040
    },
    {
        "Rank": 28,
        "Country": "United States",
        "Airport": "Seattle-Tacoma International Airport",
        "Number of Passengers": 50877260
    },
    {
        "Rank": 29,
        "Country": "United States",
        "Airport": "San Francisco International Airport",
        "Number of Passengers": 50196094
    },
    {
        "Rank": 30,
        "Country": "Spain",
        "Airport": "Aeropuerto de Barcelona-El Prat",
        "Number of Passengers": 49883928
    },
    {
        "Rank": 31,
        "Country": "United States",
        "Airport": "Newark Liberty International Airport",
        "Number of Passengers": 49084744
    },
    {
        "Rank": 32,
        "Country": "Indonesia",
        "Airport": "Soekarno-Hatta International Airport",
        "Number of Passengers": 49080532
    },
    {
        "Rank": 33,
        "Country": "United States",
        "Airport": "Sky Harbor International Airport",
        "Number of Passengers": 48654432
    },
    {
        "Rank": 34,
        "Country": "Mexico",
        "Airport": "Aeropuerto Internacional de la Ciudad de México",
        "Number of Passengers": 48416008
    },
    {
        "Rank": 35,
        "Country": "Malaysia",
        "Airport": "Kuala Lumpur International Airport",
        "Number of Passengers": 47242468
    },
    {
        "Rank": 36,
        "Country": "United States",
        "Airport": "George Bush Intercontinental Airport",
        "Number of Passengers": 46168662
    },
    {
        "Rank": 37,
        "Country": "Qatar",
        "Airport": "Hamad International Airport",
        "Number of Passengers": 45916098
    },
    {
        "Rank": 38,
        "Country": "Philippines",
        "Airport": "Ninoy Aquino International Airport",
        "Number of Passengers": 45300322
    },
    {
        "Rank": 39,
        "Country": "China",
        "Airport": "Chengdu Tianfu International Airport",
        "Number of Passengers": 44786032
    },
    {
        "Rank": 40,
        "Country": "Canada",
        "Airport": "Toronto Pearson International Airport",
        "Number of Passengers": 44761805
    },
    {
        "Rank": 41,
        "Country": "China",
        "Airport": "Chongqing Jiangbei International Airport",
        "Number of Passengers": 44657268
    },
    {
        "Rank": 42,
        "Country": "Saudi Arabia",
        "Airport": "King Abulaziz International Airport",
        "Number of Passengers": 42910407
    },
    {
        "Rank": 43,
        "Country": "China",
        "Airport": "Hongqiao International Airport",
        "Number of Passengers": 42492745
    },
    {
        "Rank": 44,
        "Country": "China",
        "Airport": "Kunming International Airport",
        "Number of Passengers": 42053214
    },
    {
        "Rank": 45,
        "Country": "China",
        "Airport": "Xi'an-Xianyang International Airport",
        "Number of Passengers": 41371228
    },
    {
        "Rank": 46,
        "Country": "Brazil",
        "Airport": "Guarulhos International Airport",
        "Number of Passengers": 41307919
    },
    {
        "Rank": 47,
        "Country": "China",
        "Airport": "Hangzhou Xiaoshan International Airport",
        "Number of Passengers": 41170470
    },
    {
        "Rank": 48,
        "Country": "United Kingdom",
        "Airport": "Gatwick Airport",
        "Number of Passengers": 40905856
    },
    {
        "Rank": 49,
        "Country": "United States",
        "Airport": "Logan International Airport",
        "Number of Passengers": 40861658
    },
    {
        "Rank": 50,
        "Country": "Vietnam",
        "Airport": "Tan Son Nhat International Airport",
        "Number of Passengers": 40738295
    },
    {
        "Rank": 51,
        "Country": "Italy",
        "Airport": "Aeroporto di Roma-Fiumicino",
        "Number of Passengers": 40494654
    },
    {
        "Rank": 52,
        "Country": "Colombia",
        "Airport": "Aeropuerto Internacional El Dorado",
        "Number of Passengers": 39485864
    },
    {
        "Rank": 53,
        "Country": "Hong Kong SAR",
        "Airport": "Hong Kong International Airport",
        "Number of Passengers": 39452633
    },
    {
        "Rank": 54,
        "Country": "China",
        "Airport": "Beijing Daxing International Airport",
        "Number of Passengers": 39410776
    },
    {
        "Rank": 55,
        "Country": "Australia",
        "Airport": "Sydney International Airport",
        "Number of Passengers": 38648802
    },
    {
        "Rank": 56,
        "Country": "India",
        "Airport": "Kempegowda International Airport",
        "Number of Passengers": 37202111
    },
    {
        "Rank": 57,
        "Country": "Turkey",
        "Airport": "Sabiha Gokcen International Airport",
        "Number of Passengers": 37098432
    },
    {
        "Rank": 58,
        "Country": "Germany",
        "Airport": "Munich Airport",
        "Number of Passengers": 37037070
    },
    {
        "Rank": 59,
        "Country": "Russian Federation",
        "Airport": "Sheremetyevo International Airport",
        "Number of Passengers": 36574848
    },
    {
        "Rank": 60,
        "Country": "Turkey",
        "Airport": "Antalya International Airport",
        "Number of Passengers": 35538387
    }
]
"""

# Parse the JSON string
airport_data = json.loads(json_data)

# Filter for airports in the United States and select the top 10 by passengers
us_airports = [entry for entry in airport_data if entry["Country"] == "United States"]
top_10_us_airports = sorted(us_airports, key=lambda x: x["Number of Passengers"], reverse=True)[:10]

# Print the top 10 US airports
print("Top 10 Busiest Airports in the United States:")
for airport in top_10_us_airports:
    print(f"Rank {airport['Rank']}: {airport['Airport']} - {airport['Number of Passengers']} Passengers")
# Out:
# Top 10 Busiest Airports in the United States:
# Rank 1: Hartsfield-Jackson Atlanta International Airport - 104653451 Passengers
# Rank 3: Dallas/Ft Worth International Airport - 81755538 Passengers
# Rank 6: Denver International Airport - 77837917 Passengers
# Rank 8: Los Angeles International Airport - 75050875 Passengers
# Rank 9: O'Hare International Airport - 73894226 Passengers
# Rank 13: John F. Kennedy International Airport - 62464331 Passengers
# Rank 18: Orlando International Airport - 57735726 Passengers
# Rank 19: McCarran International Airport - 57666456 Passengers
# Rank 22: Charlotte Douglas International Airport - 53445770 Passengers
# Rank 25: Miami International Airport - 52340934 Passengers
